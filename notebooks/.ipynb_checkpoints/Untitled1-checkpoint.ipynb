# %%
import os
import pandas as pd
DATA_DIR = os.path.join("..", "data", "raw")
ace_violations = pd.read_csv(os.path.join(DATA_DIR, "ACE_violations_JAN.csv"))
ace_violations.head()
# Out:
#    Violation ID                                         Vehicle ID  \
# 0     352355258  f31034de7883a465d002e8c0127ab6b95de01e09afadda...
# 1     352346872  bf3d0479941a22f007ef21e7ae06eb0003c93c7278d80d...
# 2     352342761  ab6acec9f497d9a2989280c2a81282e4f86a868bf39680...
# 3     352338288  988cb49a3b86fab1cd82ca4d32c9b2f29dfb83cbbcb06d...
# 4     352335635  ec80d0f3597854dd89612aaf2942cd3646bf7d1b0f0a00...
#
#          First Occurrence         Last Occurrence  Violation Status  \
# 0  01/31/2023 06:11:26 PM  01/31/2023 06:20:57 PM  VIOLATION ISSUED
# 1  01/31/2023 05:26:00 PM  01/31/2023 05:43:00 PM  VIOLATION ISSUED
# 2  01/31/2023 04:35:00 PM  01/31/2023 05:03:00 PM  VIOLATION ISSUED
# 3  01/31/2023 04:04:00 PM  01/31/2023 04:24:00 PM  VIOLATION ISSUED
# 4  01/31/2023 03:48:00 PM  01/31/2023 04:12:00 PM  VIOLATION ISSUED
#
#     Violation Type Bus Route ID  Violation Latitude  Violation Longitude  \
# 0  MOBILE BUS LANE         B44+           40.633496           -73.947606
# ...
